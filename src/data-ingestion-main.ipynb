# %%
from langchain_chroma import Chroma
import fitz
import torch
from langchain_community.document_loaders.parsers import PyMuPDFParser
from langchain_core.documents.base import Blob
from langchain_core.documents import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from transformers import CLIPProcessor,CLIPModel
from PIL import Image
import base64
import io
import camelot
import pdfplumber
import pandas as pd

# %%
file_path="../data/sample/Nvidia/nvidia_2023.pdf"

model=CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor=CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

splitter=RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=30
)
docs=fitz.open(file_path)

# %%
model.eval()
# Out:
# CLIPModel(
#   (text_model): CLIPTextTransformer(
#     (embeddings): CLIPTextEmbeddings(
#       (token_embedding): Embedding(49408, 512)
#       (position_embedding): Embedding(77, 512)
#     )
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPSdpaAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (layer_norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#           (layer_norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (vision_model): CLIPVisionTransformer(
#     (embeddings): CLIPVisionEmbeddings(
#       (patch_embedding): Conv2d(3, 768, kernel_size=(32, 32), stride=(32, 32), bias=False)
#       (position_embedding): Embedding(50, 768)
#     )
#     (pre_layrnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPSdpaAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (layer_norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (layer_norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (visual_projection): Linear(in_features=768, out_features=512, bias=False)
#   (text_projection): Linear(in_features=512, out_features=512, bias=False)
# )

# %%
def embed_text(text):
    inputs=processor(
        text=text,
        return_tensors='pt',
        padding=True,
        truncation=True,
        max_length=77
    )
    with torch.no_grad():
        features=model.get_text_features(**inputs)

        #normalize embeddings
        features=features/features.norm(dim=-1,keepdim=True)
        return features.squeeze().numpy()

# %%
def embed_image(image_data):
    if isinstance(image_data,str):
        image=Image.Open(image_data).convert("RGB")
    else: 
        image=image_data

    inputs=processor(images=image,return_tensors='pt')

    with torch.no_grad():
        features=model.get_image_features(**inputs)

        features=features/features.norm(dim=-1,keepdim=True)

        return features.squeeze().numpy()

# %%
## FUNCTION TO EXTRACT TABLEDS from the page or the doc

def extract_tables_from_page(file_path: str, page_num: int):
    """Extract *only real tables* from a given PDF page using Camelot or pdfplumber.
    Returns a list of extracted tables, or an empty list if none found."""
    
    tables_data = []

    def is_valid_table(df):
        """Heuristic filter to detect real tables (not paragraphs)."""
        # Must have at least 2 rows and 2 columns
        if df.shape[0] < 2 or df.shape[1] < 2:
            return False
        
        # Reject if there's only one long text cell (likely paragraph)
        avg_len = df.applymap(lambda x: len(str(x)) if x else 0).mean().mean()
        if avg_len > 100:  # large cell content => not a table
            return False
        
        # Reject empty or NaN-heavy tables
        if df.isnull().mean().mean() > 0.8:
            return False
        
        return True

    # 1️⃣ Camelot lattice
    try:
        tables = camelot.read_pdf(file_path, pages=str(page_num + 1), flavor='lattice')
        if tables:
            for idx, table in enumerate(tables):
                df = table.df
                if is_valid_table(df):
                    tables_data.append({
                        "table_num": idx,
                        "content": df.to_markdown(index=True),
                        "method": "camelot-lattice"
                    })
                
            if tables_data:
                return tables_data
    except Exception as e:
        print(f"Camelot lattice extraction failed on page {page_num}: {e}")

    # 2️⃣ Camelot stream
    try:
        tables = camelot.read_pdf(file_path, pages=str(page_num + 1), flavor='stream')
        if tables:
            for idx, table in enumerate(tables):
                df = table.df
                if is_valid_table(df):
                    tables_data.append({
                        "table_num": idx,
                        "content": df.to_markdown(index=True),
                        "method": "camelot-stream"
                    })
            if tables_data:
                return tables_data
    except Exception as e:
        print(f"Camelot stream extraction failed on page {page_num}: {e}")

    # 3️⃣ pdfplumber
    try:
        with pdfplumber.open(file_path) as pdf:
            page = pdf.pages[page_num]
            tables = page.extract_tables()
            if tables:
                for idx, table in enumerate(tables):
                    df = pd.DataFrame(table)
                    if is_valid_table(df):
                        tables_data.append({
                            "table_num": idx,
                            "content": df.to_markdown(index=True),
                            "method": "pdfplumber"
                        })
                if tables_data:
                    return tables_data
    except Exception as e:
        print(f"pdfplumber extraction failed on page {page_num}: {e}")

    return []

# %%
import os
from dotenv import load_dotenv

load_dotenv()

def generate_table_summary(table_text: str):
    """
    Uses Gemini (via LangChain) to create a short natural-language summary of the table.
    You can plug this function into your table extraction pipeline.
    """
    try:
        from langchain_google_genai import ChatGoogleGenerativeAI
        from langchain.prompts import ChatPromptTemplate

        api_key = os.getenv("GEMINI_API_KEY")

        if not api_key:
            raise ValueError("Missing GEMINI_API_KEY in environment variables.")

        llm = ChatGoogleGenerativeAI(model="gemini-2.5-pro", temperature=0.3, google_api_key=api_key)

        # Prompt template
        prompt = ChatPromptTemplate.from_template(
            """You are a data summarizer. Summarize the key content of the following table in one or two sentences. 
            Focus on what the table represents, not exact numbers.

            Table:
            {table_text}
            """
        )

        # Combine prompt + LLM
        chain = prompt | llm

        # Run the chain
        summary = chain.invoke({"table_text": table_text}).content.strip()
        return summary

    except Exception as e:
        print(f"[WARN] Table summary generation failed: {e}")
        return "A table containing structured data extracted from the document."

# %%
print(docs.page_count)
print(docs[40].get_text('html'))
all_docs=[]
all_embeddings=[]
image_data_store={}
# Out:
# 169
# <div id="page0" style="width:612.0pt;height:792.0pt">
# <p style="top:23.9pt;left:18.2pt;line-height:7.2pt"><span style="font-family:Arial,sans-serif;font-size:7.2pt;color:#0000ff">Table of Contents</span></p>
# <p style="top:62.3pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">We recognize the benefit from a tax position only if it is more-likely-than-not that the position would be sustained upon audit based solely on the</span></p>
# <p style="top:73.1pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">technical merits of the tax position. Our policy is to include interest and penalties related to unrecognized tax benefits as a component of income</span></p>
# <p style="top:83.9pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">tax expense.</span></p>
# <p style="top:105.5pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Refer to Note 14 of the Notes to the Consolidated Financial Statements in Part IV, Item 15 of this Annual Report on Form 10-K for additional</span></p>
# <p style="top:116.3pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">information.</span></p>
# <p style="top:137.9pt;left:18.2pt;line-height:9.0pt"><b><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#76b900">Change in Accounting Estimate</span></b></p>
# <p style="top:159.5pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">In February 2023, we completed an assessment of the useful lives of our property, plant, and equipment. Based on advances in technology and</span></p>
# <p style="top:170.3pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">usage rate, we increased the estimated useful life of a majority of the server, storage, and network equipment from three years to a range of four</span></p>
# <p style="top:181.1pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">to five years, and assembly and test equipment from five years to seven years. This change in accounting estimate became effective at the</span></p>
# <p style="top:191.9pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">beginning of fiscal year 2024. Based on the carrying amounts of a majority of our server, storage, network, and assembly and test equipment,</span></p>
# <p style="top:202.7pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">net in use as of the end of fiscal year 2023, it is estimated this change will increase our fiscal year 2024 operating income by $133&#xa0;million as a</span></p>
# <p style="top:213.5pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">result of the reduction in depreciation expense.</span></p>
# <p style="top:235.1pt;left:18.2pt;line-height:9.9pt"><b><span style="font-family:Arial,sans-serif;font-size:9.9pt;color:#76b900">Results of Operations</span></b></p>
# <p style="top:252.7pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">A discussion regarding our financial condition and results of operations for fiscal year 2023 compared to fiscal year 2022 is presented below. A</span></p>
# <p style="top:263.5pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">discussion regarding our financial condition and results of operations for fiscal year 2022 compared to fiscal year 2021 can be found under Item</span></p>
# <p style="top:274.3pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">7 in our Annual Report on Form 10-K for the fiscal year ended January&#xa0;30, 2022, filed with the SEC on March&#xa0;18, 2022, which is available free of</span></p>
# <p style="top:285.1pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">charge on the SEC&#x2019;s website at http://www.sec.gov and at our investor relations website, http://investor.nvidia.com.</span></p>
# <p style="top:304.0pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">The following table sets forth, for the periods indicated, certain items in our Consolidated Statements of Income expressed as a percentage of</span></p>
# <p style="top:314.8pt;left:18.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">revenue.&#xa0;</span></p>
# <p style="top:335.7pt;left:19.1pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">&#xa0;&#xa0;</span></p>
# <p style="top:335.7pt;left:474.1pt;line-height:9.0pt"><b><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Year Ended</span></b></p>
# <p style="top:357.3pt;left:19.1pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">&#xa0;</span></p>
# <p style="top:347.9pt;left:425.1pt;line-height:9.0pt"><b><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">January 29,</span></b></p>
# <p style="top:356.6pt;left:439.9pt;line-height:9.0pt"><b><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">2023</span></b></p>
# <p style="top:347.9pt;left:522.5pt;line-height:9.0pt"><b><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">January 30,</span></b></p>
# <p style="top:356.6pt;left:537.2pt;line-height:9.0pt"><b><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">2022</span></b></p>
# <p style="top:369.5pt;left:19.1pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Revenue</span></p>
# <p style="top:369.5pt;left:461.0pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">100.0&#xa0;%</span></p>
# <p style="top:369.5pt;left:558.4pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">100.0&#xa0;%</span></p>
# <p style="top:381.6pt;left:29.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Cost of revenue</span></p>
# <p style="top:380.9pt;left:466.0pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">43.1&#xa0;</span></p>
# <p style="top:380.9pt;left:563.4pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">35.1&#xa0;</span></p>
# <p style="top:393.8pt;left:19.1pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Gross profit</span></p>
# <p style="top:393.8pt;left:466.0pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">56.9&#xa0;</span></p>
# <p style="top:393.8pt;left:563.4pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">64.9&#xa0;</span></p>
# <p style="top:405.2pt;left:19.1pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Operating expenses</span></p>
# <p style="top:405.2pt;left:405.7pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">&#xa0;</span></p>
# <p style="top:417.4pt;left:29.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Research and development</span></p>
# <p style="top:417.4pt;left:466.0pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">27.2&#xa0;</span></p>
# <p style="top:417.4pt;left:563.4pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">19.6&#xa0;</span></p>
# <p style="top:428.9pt;left:29.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Sales, general and administrative</span></p>
# <p style="top:428.9pt;left:471.0pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">9.1&#xa0;</span></p>
# <p style="top:428.9pt;left:568.4pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">8.0&#xa0;</span></p>
# <p style="top:440.3pt;left:29.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Acquisition termination cost</span></p>
# <p style="top:440.3pt;left:471.0pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">5.0&#xa0;</span></p>
# <p style="top:440.3pt;left:571.9pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">&#x2014;&#xa0;</span></p>
# <p style="top:453.2pt;left:51.5pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Total operating expenses</span></p>
# <p style="top:452.5pt;left:466.0pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">41.3&#xa0;</span></p>
# <p style="top:452.5pt;left:563.4pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">27.6&#xa0;</span></p>
# <p style="top:465.3pt;left:19.1pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Income from operations</span></p>
# <p style="top:465.3pt;left:466.0pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">15.6&#xa0;</span></p>
# <p style="top:465.3pt;left:563.4pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">37.3&#xa0;</span></p>
# <p style="top:476.8pt;left:29.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Interest income</span></p>
# <p style="top:476.8pt;left:471.0pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">1.0&#xa0;</span></p>
# <p style="top:476.8pt;left:568.4pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">0.1&#xa0;</span></p>
# <p style="top:488.9pt;left:29.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Interest expense</span></p>
# <p style="top:488.9pt;left:467.5pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">(1.0)</span></p>
# <p style="top:488.9pt;left:564.9pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">(0.9)</span></p>
# <p style="top:501.1pt;left:29.2pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Other, net</span></p>
# <p style="top:500.4pt;left:467.5pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">(0.1)</span></p>
# <p style="top:500.4pt;left:568.4pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">0.4&#xa0;</span></p>
# <p style="top:513.2pt;left:51.5pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Other income (expense), net</span></p>
# <p style="top:513.2pt;left:467.5pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">(0.1)</span></p>
# <p style="top:513.2pt;left:564.9pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">(0.4)</span></p>
# <p style="top:525.4pt;left:19.1pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Income before income tax</span></p>
# <p style="top:525.4pt;left:466.0pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">15.5&#xa0;</span></p>
# <p style="top:525.4pt;left:563.4pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">36.9&#xa0;</span></p>
# <p style="top:537.5pt;left:19.1pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Income tax expense (benefit)</span></p>
# <p style="top:537.5pt;left:467.5pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">(0.7)</span></p>
# <p style="top:537.5pt;left:568.4pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">0.7&#xa0;</span></p>
# <p style="top:551.0pt;left:19.1pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">Net income</span></p>
# <p style="top:549.7pt;left:466.0pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">16.2&#xa0;%</span></p>
# <p style="top:549.7pt;left:563.4pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">36.2&#xa0;%</span></p>
# <p style="top:595.6pt;left:301.1pt;line-height:9.0pt"><span style="font-family:Arial,sans-serif;font-size:9.0pt;color:#000000">41</span></p>
# </div>

# %%
for i,page in enumerate(docs):
    
    ### processing text cotent of the page
    text=page.get_text()
    if text.strip():
        temp_doc=Document(page_content=text,metadata={"page":i,"type":"text"})
        text_chunks=splitter.split_documents([temp_doc])

        for chunk in text_chunks:
            all_docs.append(chunk)
            embedding=embed_text(chunk.page_content)
            all_embeddings.append(embedding)
    

    #### processing image content of the page

    for img_i,img in enumerate(page.get_images(full=True)):
        try:
            xref=img[0]
            base_image=docs.extract_image(xref)
            image_bytes=base_image['image']

            ###convert to PIL Image
            pil_image=Image.open(io.BytesIO(image_bytes)).convert('RGB')

            # pil_image.show()

            image_id=f"page: {i}_img_{img_i}"

            #save the image bytes in base64 format for mdoel use
            buffered=io.BytesIO()
            pil_image.save(buffered,format="PNG")
            img_base64=base64.b64encode(buffered.getvalue()).decode()
            image_data_store[image_id]=img_base64

            #now create embeddings of image and store

            all_embeddings.append(embed_image(pil_image))
            img_doc=Document(
                page_content=f"[Image: {image_id}]",
                metadata={"page":i,"type":"image","image_id":image_id}
            )
            all_docs.append(img_doc)
        except Exception as e:
            print(f"Error processing image {img_i} on page {i}: {e}")
            continue  
    
    ### EXTRACTING TAABLE FOR THE PAGE
    tables=extract_tables_from_page(docs,i)
    if tables:
        for table in tables:
            table_summary=generate_table_summary(table['content'])
            table_doc=Document(
                page_content=f"This table was extracted from page {i}. "
                             f"Summary: {table_summary}\n\n"
                             f"Table data:\n{table['content']}",
                metadata={
                    "page":i,
                    "type":"table",
                    "method":table['method'],
                    "table_num":table['table_num'],   
                }
            )
            #creating embedding for the table
            table_embed=embed_text(table_doc.page_content)
            all_docs.append(table_doc)
            all_embeddings.append(table_embed)
            

docs.close()
# Out:
# Camelot lattice extraction failed on page 0: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 0: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 0: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 1: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 1: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 1: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 2: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 2: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 2: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 3: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 3: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 3: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 4: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 4: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 4: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 5: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 5: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 5: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 6: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 6: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 6: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 7: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 7: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 7: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 8: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 8: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 8: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 9: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 9: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 9: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 10: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 10: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 10: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 11: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 11: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 11: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 12: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 12: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 12: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 13: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 13: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 13: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 14: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 14: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 14: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 15: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 15: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 15: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 16: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 16: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 16: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 17: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 17: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 17: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 18: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 18: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 18: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 19: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 19: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 19: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 20: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 20: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 20: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 21: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 21: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 21: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 22: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 22: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 22: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 23: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 23: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 23: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 24: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 24: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 24: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 25: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 25: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 25: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 26: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 26: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 26: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 27: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 27: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 27: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 28: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 28: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 28: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 29: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 29: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 29: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 30: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 30: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 30: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 31: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 31: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 31: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 32: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 32: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 32: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 33: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 33: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 33: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 34: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 34: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 34: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 35: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 35: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 35: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 36: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 36: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 36: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 37: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 37: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 37: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 38: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 38: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 38: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 39: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 39: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 39: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 40: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 40: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 40: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 41: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 41: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 41: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 42: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 42: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 42: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 43: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 43: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 43: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 44: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 44: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 44: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 45: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 45: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 45: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 46: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 46: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 46: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 47: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 47: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 47: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 48: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 48: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 48: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 49: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 49: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 49: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 50: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 50: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 50: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 51: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 51: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 51: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 52: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 52: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 52: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 53: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 53: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 53: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 54: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 54: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 54: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 55: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 55: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 55: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 56: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 56: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 56: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 57: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 57: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 57: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 58: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 58: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 58: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 59: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 59: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 59: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 60: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 60: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 60: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 61: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 61: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 61: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 62: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 62: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 62: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 63: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 63: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 63: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 64: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 64: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 64: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 65: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 65: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 65: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 66: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 66: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 66: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 67: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 67: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 67: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 68: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 68: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 68: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 69: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 69: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 69: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 70: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 70: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 70: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 71: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 71: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 71: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 72: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 72: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 72: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 73: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 73: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 73: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 74: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 74: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 74: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 75: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 75: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 75: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 76: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 76: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 76: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 77: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 77: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 77: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 78: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 78: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 78: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 79: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 79: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 79: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 80: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 80: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 80: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 81: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 81: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 81: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 82: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 82: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 82: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 83: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 83: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 83: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 84: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 84: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 84: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 85: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 85: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 85: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 86: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 86: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 86: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 87: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 87: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 87: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 88: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 88: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 88: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 89: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 89: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 89: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 90: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 90: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 90: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 91: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 91: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 91: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 92: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 92: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 92: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 93: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 93: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 93: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 94: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 94: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 94: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 95: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 95: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 95: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 96: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 96: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 96: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 97: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 97: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 97: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 98: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 98: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 98: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 99: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 99: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 99: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 100: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 100: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 100: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 101: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 101: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 101: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 102: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 102: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 102: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 103: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 103: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 103: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 104: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 104: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 104: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 105: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 105: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 105: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 106: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 106: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 106: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 107: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 107: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 107: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 108: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 108: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 108: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 109: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 109: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 109: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 110: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 110: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 110: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 111: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 111: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 111: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 112: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 112: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 112: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 113: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 113: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 113: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 114: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 114: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 114: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 115: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 115: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 115: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 116: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 116: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 116: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 117: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 117: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 117: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 118: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 118: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 118: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 119: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 119: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 119: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 120: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 120: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 120: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 121: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 121: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 121: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 122: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 122: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 122: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 123: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 123: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 123: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 124: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 124: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 124: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 125: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 125: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 125: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 126: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 126: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 126: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 127: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 127: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 127: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 128: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 128: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 128: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 129: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 129: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 129: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 130: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 130: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 130: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 131: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 131: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 131: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 132: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 132: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 132: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 133: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 133: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 133: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 134: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 134: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 134: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 135: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 135: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 135: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 136: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 136: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 136: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 137: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 137: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 137: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 138: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 138: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 138: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 139: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 139: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 139: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 140: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 140: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 140: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 141: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 141: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 141: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 142: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 142: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 142: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 143: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 143: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 143: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 144: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 144: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 144: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 145: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 145: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 145: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 146: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 146: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 146: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 147: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 147: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 147: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 148: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 148: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 148: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 149: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 149: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 149: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 150: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 150: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 150: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 151: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 151: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 151: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 152: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 152: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 152: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 153: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 153: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 153: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 154: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 154: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 154: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 155: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 155: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 155: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 156: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 156: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 156: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 157: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 157: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 157: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 158: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 158: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 158: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 159: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 159: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 159: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 160: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 160: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 160: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 161: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 161: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 161: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 162: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 162: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 162: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 163: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 163: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 163: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 164: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 164: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 164: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 165: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 165: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 165: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 166: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 166: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 166: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 167: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 167: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 167: 'Document' object has no attribute 'seek'
# Camelot lattice extraction failed on page 168: 'Document' object has no attribute 'seek'
# Camelot stream extraction failed on page 168: 'Document' object has no attribute 'seek'
# pdfplumber extraction failed on page 168: 'Document' object has no attribute 'seek'

# %%
all_docs[40]
# Out:
# Document(metadata={'page': 4, 'type': 'text'}, page_content='The Compute & Networking segment includes our Data Center accelerated computing platform; networking; automotive AI Cockpit, autonomous\ndriving development agreements, and autonomous vehicle solutions; electric vehicle computing platforms; Jetson for robotics and other\nembedded platforms; NVIDIA AI Enterprise and other software; and cryptocurrency mining processors, or CMP.')

# %%
import numpy as np
embeddings_array=np.array(all_embeddings)
embeddings_array
# Out:
# array([[-0.01287598,  0.04877269, -0.03023132, ..., -0.00654506,
#         -0.00766676,  0.00073045],
#        [-0.01041544, -0.01405487, -0.01962452, ...,  0.05553675,
#         -0.00819241, -0.04919571],
#        [ 0.0227439 , -0.00631156, -0.01333825, ...,  0.06064708,
#          0.00826883, -0.04080103],
#        ...,
#        [ 0.03837572, -0.00354057, -0.02518085, ...,  0.04864152,
#          0.00831235, -0.02403388],
#        [ 0.01557035,  0.0022552 , -0.00702683, ...,  0.07278122,
#          0.00739336, -0.0662268 ],
#        [ 0.00908183,  0.03708636,  0.00511615, ..., -0.02527341,
#          0.00203589, -0.0146383 ]], dtype=float32)

# %%
(all_docs,embeddings_array)
# Out:
# ([Document(metadata={'page': 0, 'type': 'text'}, page_content='Table of Contents\nUNITED STATES\nSECURITIES AND EXCHANGE COMMISSION\nWashington, D.C.\xa020549\n____________________________________________________________________________________________\nFORM 10-K\n☒\nANNUAL REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934\n\xa0\xa0\xa0\xa0For the fiscal year ended January\xa029, 2023\nOR\n☐\nTRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934\nCommission file number: 0-23985\n\xa0\n\xa0\nNVIDIA CORPORATION'),
#   Document(metadata={'page': 0, 'type': 'text'}, page_content='NVIDIA CORPORATION\n(Exact name of registrant as specified in its charter)\nDelaware\n94-3177549\n(State or other jurisdiction of\n(I.R.S. Employer\nIncorporation or Organization)\nIdentification No.)\n2788 San Tomas Expressway\nSanta Clara, California\xa095051\n(408) 486-2000\n(Address, including zip code, and telephone number, including area code, of principal executive offices)\nSecurities registered pursuant to Section 12(b) of the Act:\nTitle of each class\nTrading Symbol(s)'),
#   Document(metadata={'page': 0, 'type': 'text'}, page_content='Trading Symbol(s)\nName of each exchange on which registered\nCommon Stock, $0.001 par value per share\nNVDA\nThe Nasdaq Global Select Market\nSecurities registered pursuant to Section 12(g) of the Act:\nNone\nIndicate by check mark if the registrant is a well-known seasoned issuer, as defined in Rule 405 of the Securities Act.\xa0\xa0\xa0\xa0Yes ☐ No ☒\nIndicate by check mark if the registrant is not required to file reports pursuant to Section 13 or Section 15(d) of the Act.\xa0\xa0\xa0\xa0Yes ☐ No ☒'),
#   Document(metadata={'page': 0, 'type': 'text'}, page_content='Indicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the preceding 12\nmonths (or for such shorter period that the registrant was required to file such reports), and (2) has been subject to such filing requirements for the past 90 days.\xa0\xa0\xa0\xa0Yes ☒ No ☐'),
#   Document(metadata={'page': 0, 'type': 'text'}, page_content='Indicate by check mark whether the registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule 405 of Regulation S-T (§232.405 of\nthis chapter) during the preceding 12 months (or for such shorter period that the registrant was required to submit such files).\xa0\xa0\xa0\xa0Yes ☒ No ☐'),
#   Document(metadata={'page': 0, 'type': 'text'}, page_content='Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller reporting company, or an emerging growth company.\nSee the definitions of “large accelerated filer," “accelerated filer," “smaller reporting company," and "emerging growth company" in Rule 12b-2 of the Exchange Act.\nLarge accelerated filer ☒\nAccelerated filer\n☐\nNon-accelerated filer\n☐\nSmaller reporting\ncompany\n☐\nEmerging growth\ncompany\n☐'),
#   Document(metadata={'page': 0, 'type': 'text'}, page_content='☐\nEmerging growth\ncompany\n☐\nIf an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying with any new or revised financial\naccounting standards provided pursuant to Section 13(a) of the Exchange Act.\xa0\xa0\xa0\xa0☐\nIndicate by check mark whether the registrant has filed a report on and attestation to its management’s assessment of the effectiveness of its internal control over financial reporting'),
#   Document(metadata={'page': 0, 'type': 'text'}, page_content='under Section 404(b) of the Sarbanes-Oxley Act (15 U.S.C. 7262(b)) by the registered public accounting firm that prepared or issued its audit report. ☒\nIf securities are registered pursuant to Section 12(b) of the Act, indicate by check mark whether the financial statements of the registrant included in the filing reflect the correction of\nan error to previously issued financial statements. ☐'),
#   Document(metadata={'page': 0, 'type': 'text'}, page_content='Indicate by check mark whether any of those error corrections are restatements that required a recovery analysis of incentive-based compensation received by any of the registrant’s\nexecutive officers during the relevant recovery period pursuant to §240.10D-1(b). ☐\nIndicate by check mark whether the registrant is a shell company (as defined in Rule 12b-2 of the Act).\xa0\xa0\xa0\xa0Yes ☐ No ☒'),
#   Document(metadata={'page': 0, 'type': 'text'}, page_content="The aggregate market value of the voting stock held by non-affiliates of the registrant as of July\xa029, 2022 was approximately $434.37 billion (based on the closing sales price of the\nregistrant's common stock as reported by the Nasdaq Global Select Market on July\xa029, 2022). This calculation excludes 98 million shares held by directors and executive officers of"),
#   Document(metadata={'page': 0, 'type': 'text'}, page_content="the registrant. This calculation does not exclude shares held by such organizations whose ownership exceeds 5% of the registrant's outstanding common stock that have\nrepresented to the registrant that they are registered investment advisers or investment companies registered under section 8 of the Investment Company Act of 1940.\nThe number of shares of common stock outstanding as of February\xa017, 2023 was 2.47\xa0billion.\nDOCUMENTS INCORPORATED BY REFERENCE"),
#   Document(metadata={'page': 0, 'type': 'text'}, page_content="Portions of the registrant's Proxy Statement for its 2023 Annual Meeting of Shareholders to be filed with the Securities and Exchange Commission pursuant to Regulation 14A not\nlater than 120 days after the end of the fiscal year covered by this Annual Report on Form 10-K are incorporated by reference into Part III, Items 10-14 of this Annual Report on Form\n10-K."),
#   Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page: 0_img_0'}, page_content='[Image: page: 0_img_0]'),
#   Document(metadata={'page': 1, 'type': 'text'}, page_content='Table of Contents\nNVIDIA CORPORATION\nTABLE OF CONTENTS\n\xa0\n\xa0\nPage\n\xa0\n\xa0\nPART I\n\xa0\nItem 1.\nBusiness\n\xa04\nItem 1A.\nRisk Factors\n\xa015\nItem 1B.\nUnresolved Staff Comments\n\xa033\nItem 2.\nProperties\n\xa033\nItem 3.\nLegal Proceedings\n\xa034\nItem 4.\nMine Safety Disclosures\n\xa034\n\xa0\nPART II\n\xa0\n\xa0\nItem 5.\nMarket for Registrant’s Common Equity, Related Stockholder Matters and Issuer Purchases of Equity Securities\n\xa034\nItem 6.\n[Reserved]\n35\nItem 7.'),
#   Document(metadata={'page': 1, 'type': 'text'}, page_content='Item 6.\n[Reserved]\n35\nItem 7.\nManagement’s Discussion and Analysis of Financial Condition and Results of Operations\n\xa036\nItem 7A.\nQuantitative and Qualitative Disclosures About Market Risk\n\xa046\nItem 8.\nFinancial Statements and Supplementary Data\n\xa047\nItem 9.\nChanges in and Disagreements With Accountants on Accounting and Financial Disclosure\n\xa047\nItem 9A.\nControls and Procedures\n\xa047\nItem 9B.\nOther Information\n\xa048\nItem 9C.\nDisclosure Regarding Foreign Jurisdictions that Prevent Inspections\n48'),
#   Document(metadata={'page': 1, 'type': 'text'}, page_content='48\n\xa0\n\xa0\nPART III\n\xa0\nItem 10.\nDirectors, Executive Officers and Corporate Governance\n\xa048\nItem 11.\nExecutive Compensation\n\xa049\nItem 12.\nSecurity Ownership of Certain Beneficial Owners and Management and Related Stockholder Matters\n49\nItem 13.\nCertain Relationships and Related Transactions, and Director Independence\n50\nItem 14.\nPrincipal Accountant Fees and Services\n\xa050\n\xa0\n\xa0\nPART IV\n\xa0\nItem 15.\nExhibit and Financial Statement Schedules\n\xa051\nItem 16.\nForm 10-K Summary\n\xa090\nSignatures\n\xa0\n\xa091\n2'),
#   Document(metadata={'page': 2, 'type': 'text'}, page_content='Table of Contents\nWHERE YOU CAN FIND MORE INFORMATION\nInvestors and others should note that we announce material financial information to our investors using our investor relations website, press\nreleases, SEC filings and public conference calls and webcasts. We also use the following social media channels as a means of disclosing\ninformation about the company, our products, our planned financial and other announcements and attendance at upcoming investor and industry'),
#   Document(metadata={'page': 2, 'type': 'text'}, page_content='conferences, and other matters and for complying with our disclosure obligations under Regulation FD:\nNVIDIA Twitter Account (https://twitter.com/nvidia)\nNVIDIA Corporate Blog (http://blogs.nvidia.com)\nNVIDIA Facebook Page (https://www.facebook.com/nvidia)\nNVIDIA LinkedIn Page (http://www.linkedin.com/company/nvidia)\nNVIDIA Instagram Page (https://www.instagram.com/nvidia)\nIn addition, investors and others can view NVIDIA videos on YouTube (https://www.YouTube.com/nvidia).'),
#   Document(metadata={'page': 2, 'type': 'text'}, page_content="The information we post through these social media channels may be deemed material. Accordingly, investors should monitor these accounts\nand the blog, in addition to following our press releases, SEC filings and public conference calls and webcasts. This list may be updated from\ntime to time. The information we post through these channels is not a part of this Annual Report on Form 10-K. These channels may be updated\nfrom time to time on NVIDIA's investor relations website."),
#   Document(metadata={'page': 2, 'type': 'text'}, page_content="Forward-Looking Statements\nThis Annual Report on Form\xa010-K contains forward-looking statements which are based on our management's beliefs and assumptions and on\ninformation currently available to our management. In some cases, you can identify forward-looking statements by terms such as “may,” “will,”\n“should,” “could,” “goal,” “would,” “expect,” “plan,” “anticipate,” “believe,” “estimate,” “project,” “predict,” “potential” and similar expressions"),
#   Document(metadata={'page': 2, 'type': 'text'}, page_content='intended to identify forward-looking statements. These statements involve known and unknown risks, uncertainties and other factors, which may\ncause our actual results, performance, time frames or achievements to be materially different from any future results, performance, time frames\nor achievements expressed or implied by the forward-looking statements. We discuss many of these risks, uncertainties and other factors in this'),
#   Document(metadata={'page': 2, 'type': 'text'}, page_content='Annual Report on Form\xa010-K in greater detail under the heading “Risk Factors.” Given these risks, uncertainties and other factors, you should\nnot place undue reliance on these forward-looking statements. Also, these forward-looking statements represent our estimates and assumptions\nonly as of the date of this filing. You should read this Annual Report on Form\xa010-K completely and with the understanding that our actual future'),
#   Document(metadata={'page': 2, 'type': 'text'}, page_content='results may be materially different from what we expect. We hereby qualify our forward-looking statements by these cautionary statements.\nExcept as required by law, we assume no obligation to update these forward-looking statements publicly, or to update the reasons actual results\ncould differ materially from those anticipated in these forward-looking statements, even if new information becomes available in the future.'),
#   Document(metadata={'page': 2, 'type': 'text'}, page_content='All references to “NVIDIA,” “we,” “us,” “our” or the “Company” mean NVIDIA Corporation and its subsidiaries.\nIn addition, statements that “we believe” and similar statements reflect our beliefs and opinions on the relevant subject. These statements are\nbased upon information available to us as of the filing date of this Annual Report on Form 10-K, and while we believe such information forms a'),
#   Document(metadata={'page': 2, 'type': 'text'}, page_content='reasonable basis for such statements, such information may be limited or incomplete, and our statements should not be read to indicate that we\nhave conducted an exhaustive inquiry into, or review of, all potentially available relevant information. These statements are inherently uncertain\nand investors are cautioned not to unduly rely upon these statements.\n© 2023 NVIDIA Corporation. All rights reserved.\n3'),
#   Document(metadata={'page': 3, 'type': 'text'}, page_content='Table of Contents\nPART I\nITEM 1. BUSINESS\nOur Company\nNVIDIA pioneered accelerated computing to help solve the most challenging computational problems. Since our original focus on PC graphics,\nwe have expanded to several other large and important computationally intensive fields. Fueled by the sustained demand for exceptional 3D\ngraphics and the scale of the gaming market, NVIDIA has leveraged its GPU architecture to create platforms for scientific computing, artificial'),
#   Document(metadata={'page': 3, 'type': 'text'}, page_content='intelligence, or AI, data science, autonomous vehicles, or AV, robotics, metaverse and 3D internet applications.\nThe GPU was initially used to simulate human imagination, enabling the virtual worlds of video games and films. Today, it also simulates human\nintelligence, enabling a deeper understanding of the physical world. Its parallel processing capabilities, supported by thousands of computing'),
#   Document(metadata={'page': 3, 'type': 'text'}, page_content='cores, are essential to running deep learning algorithms. This form of AI, in which software writes itself by learning from large amounts of data,\ncan serve as the brain of computers, robots and self-driving cars that can perceive and understand the world. GPU-powered deep learning is\nbeing adopted by thousands of enterprises to deliver services and products that would have been immensely difficult with traditional coding.'),
#   Document(metadata={'page': 3, 'type': 'text'}, page_content='Some of the most recent applications of GPU-powered deep learning include recommendation systems, which are AI algorithms trained to\nunderstand the preferences, previous decisions, and characteristics of people and products using data gathered about their interactions, large\nlanguage models, which can recognize, summarize, translate, predict and generate text and other content based on knowledge gained from'),
#   Document(metadata={'page': 3, 'type': 'text'}, page_content='massive datasets, and generative AI, which uses algorithms that create new content, including audio, code, images, text, simulations, and\nvideos, based on the data they have been trained on.\nNVIDIA has a platform strategy, bringing together hardware, systems, software, algorithms, libraries, and services to create unique value for the\nmarkets we serve. While the computing requirements of these end markets are diverse, we address them with a unified underlying architecture'),
#   Document(metadata={'page': 3, 'type': 'text'}, page_content='leveraging our GPUs and software stacks. The programmable nature of our architecture allows us to support several multi-billion-dollar end\nmarkets with the same underlying technology by using a variety of software stacks developed either internally or by third-party developers and\npartners. The large and growing number of developers across our platforms strengthens our ecosystem and increases the value of our platform\nto our customers.'),
#   Document(metadata={'page': 3, 'type': 'text'}, page_content='to our customers.\nInnovation is at our core. We have invested over $37 billion in research and development since our inception, yielding inventions that are\nessential to modern computing. Our invention of the GPU in 1999 defined modern computer graphics and established NVIDIA as the leader in\ncomputer graphics. With our introduction of the CUDA programming model in 2006, we opened the parallel processing capabilities of our GPU'),
#   Document(metadata={'page': 3, 'type': 'text'}, page_content='for general purpose computing. This approach significantly accelerates the most demanding high-performance computing, or HPC, applications\nin fields such as aerospace, bio-science research, mechanical and fluid simulations, and energy exploration. Today, our GPUs and networking\naccelerate many of the fastest supercomputers across the world. In addition, the massively parallel compute architecture of our GPUs and'),
#   Document(metadata={'page': 3, 'type': 'text'}, page_content='associated software are well suited for deep learning and machine learning, powering the era of AI. While traditional CPU-based approaches no\nlonger deliver advances on the pace described by Moore’s Law, NVIDIA accelerated computing delivers performance improvements on a pace\nahead of Moore’s Law, giving the industry a path forward.\nGamers choose NVIDIA GPUs to enjoy immersive, increasingly cinematic virtual worlds. GPUs also help underpin the world’s fastest growing'),
#   Document(metadata={'page': 3, 'type': 'text'}, page_content='spectator sport, eSports, which attracts hundreds of millions of viewers to watch top-quality live video gaming. In addition to serving the growing\nnumber of gamers, the market for gaming GPUs is expanding because of the burgeoning population of live streamers, broadcasters, artists and\ncreators.\nResearchers and developers use our GPUs to accelerate a wide range of important applications, from simulating molecular dynamics to climate'),
#   Document(metadata={'page': 3, 'type': 'text'}, page_content='forecasting. With support for more than 2,800 applications - including 23 of the top 25 HPC applications - NVIDIA GPUs enable some of the most\npromising areas of discovery, from climate prediction to materials science and from wind tunnel simulation to genomics. Including GPUs and\nnetworking, NVIDIA powers over 70% of the supercomputers on the global TOP500 list, including 23 of the top 30 systems on the Green500 list.\n4'),
#   Document(metadata={'page': 4, 'type': 'text'}, page_content='Table of Contents\nThe world’s leading cloud service providers, or CSPs, and consumer internet companies use our GPUs and broader data center-scale\naccelerated computing platforms to enable, accelerate or enrich the services they deliver to billions of end-users, including search,\nrecommendations, social networking, online shopping, live video, translation, AI assistants, navigation, and cloud computing.'),
#   Document(metadata={'page': 4, 'type': 'text'}, page_content='A rapidly growing number of enterprises and startups across a broad range of industries use our GPUs and software to bring automation to the\nproducts and services they build. The transportation industry is turning to our platforms for autonomous driving; the healthcare industry is\nleveraging them for enhanced medical imaging and acceleration of drug discovery; and the financial services industry is using them for fraud\ndetection.'),
#   Document(metadata={'page': 4, 'type': 'text'}, page_content='detection.\nProfessional designers use our GPUs and software to create visual effects in movies and to design buildings and products ranging from cell\nphones to commercial aircraft.\nHeadquartered in Santa Clara, California, NVIDIA was incorporated in California in April 1993 and reincorporated in Delaware in April 1998.\nTermination of the Arm Share Purchase Agreement\nIn February 2022, NVIDIA and SoftBank Group Corp., or SoftBank, announced the termination of the Share Purchase Agreement whereby'),
#   Document(metadata={'page': 4, 'type': 'text'}, page_content='NVIDIA would have acquired Arm Limited, or Arm, from SoftBank. The parties agreed to terminate because of significant regulatory challenges\npreventing the completion of the transaction. We recorded an acquisition termination cost of $1.35 billion in fiscal year 2023 reflecting the write-\noff of the prepayment provided at signing.\nOur Businesses\nWe report our business results in two segments.'),
#   Document(metadata={'page': 4, 'type': 'text'}, page_content='The Compute & Networking segment includes our Data Center accelerated computing platform; networking; automotive AI Cockpit, autonomous\ndriving development agreements, and autonomous vehicle solutions; electric vehicle computing platforms; Jetson for robotics and other\nembedded platforms; NVIDIA AI Enterprise and other software; and cryptocurrency mining processors, or CMP.'),
#   Document(metadata={'page': 4, 'type': 'text'}, page_content='The Graphics segment includes GeForce GPUs for gaming and PCs, the GeForce NOW game streaming service and related infrastructure, and\nsolutions for gaming platforms; Quadro/NVIDIA RTX GPUs for enterprise workstation graphics; virtual GPU, or vGPU, software for cloud-based\nvisual and virtual computing; automotive platforms for infotainment systems; and Omniverse Enterprise software for building and operating\nmetaverse and 3D internet applications.\nOur Markets'),
#   Document(metadata={'page': 4, 'type': 'text'}, page_content='Our Markets\nWe specialize in markets in which our computing platforms can provide tremendous acceleration for applications. These platforms incorporate\nprocessors, interconnects, software, algorithms, systems, and services to deliver unique value. Our platforms address four large markets where\nour expertise is critical: Data Center, Gaming, Professional Visualization, and Automotive.\nData Center'),
#   Document(metadata={'page': 4, 'type': 'text'}, page_content='Data Center\nThe NVIDIA computing platform is focused on accelerating the most compute-intensive workloads, such as AI, data analytics, graphics and\nscientific computing, across hyperscale, cloud, enterprise, public sector, and edge data centers. The platform consists of our energy efficient\nGPUs, data processing units, or DPUs, interconnects and systems, our CUDA programming model, and a growing body of software libraries,'),
#   Document(metadata={'page': 4, 'type': 'text'}, page_content='software development kits, or SDKs, application frameworks and services, which are either available as part of the platform or packaged and\nsold separately.\nFor both AI and HPC applications, the NVIDIA accelerated computing platform greatly increases computer and data center performance and\npower efficiency relative to conventional CPU-only approaches. In the field of AI, NVIDIA’s platform accelerates both deep learning and machine'),
#   Document(metadata={'page': 4, 'type': 'text'}, page_content='learning workloads. Deep learning is a computer science approach where neural networks are trained to recognize patterns from massive\namounts of data in the form of images, sounds and text - in some instances better than humans - and in turn provide predictions in production\nuse cases. Machine learning is a related approach that leverages algorithms as well\n5'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='Table of Contents\nas data to learn how to make determinations or predictions. HPC, which includes scientific computing, uses numerical computational approaches\nto solve large and complex problems.\nWe are engaged with thousands of organizations working on AI in a multitude of industries, from automating tasks such as consumer product\nand service recommendations, to chatbots for the automation of or assistance with live customer interactions, to enabling fraud detection in'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='financial services, to optimizing oil exploration and drilling. These organizations include the world’s leading consumer internet and cloud services\ncompanies, enterprises and startups seeking to implement AI in transformative ways across multiple industries. We partner with industry leaders\nto help transform their applications or their computing platforms. We also have partnerships in transportation, retail, healthcare, and\nmanufacturing, among others, to accelerate the adoption of AI.'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='At the foundation of the NVIDIA accelerated computing platform are our GPUs, which excel at parallel workloads such as the training and\ninferencing of neural networks. They are available in industry standard servers from every major computer maker and CSP, as well as in our\nDGX AI supercomputer, a purpose-built system for deep learning and GPU accelerated applications. To facilitate customer adoption, we have'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='also built other ready-to-use system reference designs around our GPUs, including HGX for hyperscale and supercomputing data centers, EGX\nfor enterprise and edge computing, IGX for high-precision edge AI, and AGX for autonomous machines.\nIn fiscal year 2023, we introduced the Hopper architecture of data center GPUs, and started shipping the first Hopper-based GPU – the flagship'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='H100. Hopper includes a Transformer Engine, designed to accelerate the training of AI transformer models by an order of magnitude over the\nprior generation. H100 is ideal for accelerating applications such as large language models, deep recommender systems, genomics and\ncomplex digital twins.\nNVIDIA will offer enterprise customers NVIDIA AI cloud services directly and through our network of partners. Examples of these services include'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='NVIDIA DGX Cloud, which is cloud-based infrastructure and software for training AI models, and customizable pretrained AI models. NVIDIA has\npartnered with leading cloud service providers to host these services in their data centers.\nOur networking solutions include InfiniBand and Ethernet network adapters and switches, related software, and cables. This has enabled us to'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='architect end-to-end data center-scale computing platforms that can interconnect thousands of compute nodes with high-performance\nnetworking. While historically the server was the unit of computing, as AI and HPC workloads have become extremely large spanning thousands\nof compute nodes, the data center has become the new unit of computing, with networking as an integral part.'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='Beyond GPUs, NVIDIA has expanded its data center processor portfolio to include DPUs, currently shipping in the market, and CPUs with\nsamples planned to ship in the first half of fiscal year 2024. The NVIDIA Bluefield DPU is supported by foundational data-center-infrastructure-\non-a-chip software, or DOCA, that lets developers build software-defined, hardware-accelerated networking, security, storage and management'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='applications for BlueField DPUs. Partners supporting Bluefield include many of the top security, storage and networking companies. We can\noptimize across the entire computing, networking and storage stack to deliver data center-scale computing solutions. The Grace CPU is\ndesigned for AI infrastructure and high-performance computing, providing the highest performance and twice the memory bandwidth and energy-\nefficiency compared to today’s leading server chips.'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='While our approach starts with powerful chips, what makes it a full-stack computing platform is our large body of software, including the CUDA\nparallel programming model, the CUDA-X collection of application acceleration libraries, Application Programming Interfaces, or APIs, SDKs and\ntools, and domain-specific application frameworks. We also offer the NVIDIA GPU Cloud registry, or NGC, a comprehensive catalog of easy-to-'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='use, optimized software stacks across a range of domains including scientific computing, deep learning, and machine learning. With NGC, AI\ndevelopers, researchers and data scientists can get started with the development of AI and HPC applications and deploy them on DGX systems,\nNVIDIA-Certified systems from our partners, or with NVIDIA’s cloud partners.'),
#   Document(metadata={'page': 5, 'type': 'text'}, page_content='In addition to software that is delivered to customers as an integral part of our data center computing platform, we offer paid licenses to NVIDIA\nAI Enterprise, a comprehensive suite of enterprise-grade AI software; and NVIDIA vGPU software for graphics-rich virtual desktops and\nworkstations.\n6'),
#   Document(metadata={'page': 6, 'type': 'text'}, page_content='Table of Contents\nGaming\nGaming is the largest entertainment industry, with PC gaming as the predominant platform. Many factors propel computer gaming’s growth,\nincluding new high production value games and franchises, the continued rise of competitive gaming or eSports, social connectivity and the\nincreasing popularity of game streamers, modders, or gamers who create game modifications, and creators.'),
#   Document(metadata={'page': 6, 'type': 'text'}, page_content='Our gaming platforms leverage our GPUs and sophisticated software to enhance the gaming experience with smoother, higher quality graphics.\nWe developed NVIDIA RTX to bring next generation graphics and AI to games. NVIDIA RTX features ray tracing technology for real-time,\ncinematic-quality rendering. Ray tracing, which has long been used for special effects in the movie industry, is a computationally intensive'),
#   Document(metadata={'page': 6, 'type': 'text'}, page_content='technique that simulates the physical behavior of light to achieve greater realism in computer-generated scenes. NVIDIA RTX also features deep\nlearning super sampling, or NVIDIA DLSS, our AI technology that boosts frame rates while generating beautiful, sharp images for games.\nOur products for the gaming market include GeForce RTX and GeForce GTX GPUs for gaming desktop and laptop PCs, GeForce NOW cloud'),
#   Document(metadata={'page': 6, 'type': 'text'}, page_content='gaming for playing PC games on underpowered devices, SHIELD for high quality streaming on TV, as well as system-on-chips (SOCs) and\ndevelopment services for game consoles.\nIn fiscal year 2023, we introduced the GeForce RTX 40 Series of gaming GPUs, based on the Ada Lovelace architecture. The 40 Series features\nour third generation RTX technology, third generation NVIDIA DLSS, and fourth generation Tensor Cores to deliver up to 4X the performance of\nthe previous generation.'),
#   Document(metadata={'page': 6, 'type': 'text'}, page_content='the previous generation.\nProfessional Visualization\nWe serve the Professional Visualization market by working closely with independent software vendors, or ISVs, to optimize their offerings for\nNVIDIA GPUs. Our GPU computing platform enhances productivity and introduces new capabilities for critical workflows in many fields, such as\ndesign and manufacturing and digital content creation. Design and manufacturing encompass computer-aided design, architectural design,'),
#   Document(metadata={'page': 6, 'type': 'text'}, page_content='consumer-products manufacturing, medical instrumentation, and aerospace. Digital content creation includes professional video editing and\npost-production, special effects for films, and broadcast-television graphics.\nThe NVIDIA RTX platform makes it possible to render film-quality, photorealistic objects and environments with physically accurate shadows,'),
#   Document(metadata={'page': 6, 'type': 'text'}, page_content='reflections and refractions using ray tracing in real-time. Many leading 3D design and content creation applications developed by our ecosystem\npartners now support RTX, allowing professionals to accelerate and transform their workflows with NVIDIA RTX GPUs and software.\nDigital images used in product design need to mirror reality. This requires simulating the physical behavior of light and materials, or physically-'),
#   Document(metadata={'page': 6, 'type': 'text'}, page_content='based rendering. NVIDIA Omniverse is a virtual world simulation and collaboration platform for 3D workflows, such as building and operating\nmetaverse and 3D internet applications, available as a software subscription for enterprise use and free for individual use. Omniverse, virtual\nreality, or VR, and augmented reality, or AR, are being incorporated in a growing number of enterprise applications. Virtual car showrooms,'),
#   Document(metadata={'page': 6, 'type': 'text'}, page_content='surgical training, architectural walkthroughs, and bringing historical scenes to life all deploy these technologies, powered by our GPUs.\nAutomotive\nNVIDIA’s Automotive market is comprised of AV, AI cockpit, electric vehicle computing platforms, and infotainment platform solutions. Leveraging\nour technology leadership in AI and building on our long-standing automotive relationships, we are delivering a complete end-to-end solution for'),
#   Document(metadata={'page': 6, 'type': 'text'}, page_content='the AV market under the DRIVE Hyperion brand. NVIDIA has demonstrated multiple applications of AI within the car: AI can drive the car itself as\na pilot in fully autonomous mode or it can also be a co-pilot, assisting the human driver while creating a safer driving experience.\nNVIDIA is working with several hundred partners in the automotive ecosystem including automakers, truck makers, tier-one suppliers, sensor'),
#   Document(metadata={'page': 6, 'type': 'text'}, page_content='manufacturers, automotive research institutions, HD mapping companies, and startups to develop and deploy AI systems for self-driving\nvehicles. Our unified AI computing architecture starts with training deep neural networks using our GPUs, and then running a full perception,\nfusion, planning and control stack within the vehicle on the NVIDIA DRIVE Hyperion platform. The DRIVE Hyperion platform consists of the high-'),
#   Document(metadata={'page': 6, 'type': 'text'}, page_content='performance, energy efficient DRIVE AGX computing hardware, a reference sensor set that supports full self-driving capability as well as an\nopen, modular DRIVE Software\n7'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='Table of Contents\nplatform. The DRIVE Software platform includes DRIVE Chauffeur for autonomous driving, mapping and parking services, Drive Concierge for\nintelligent in-vehicle experiences, and real time conversational AI capability based on NVIDIA Omniverse Avatar software.\nIn addition, we offer a scalable data center-based simulation solution, NVIDIA DRIVE Sim, based on NVIDIA Omniverse software, for digital'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content="cockpit development, as well as for testing and validating a self-driving platform. NVIDIA's unique end-to-end, software-defined approach is\ndesigned for continuous innovation and continuous development, enabling cars to receive over-the-air updates to add new features and\ncapabilities throughout the life of a vehicle.\nBusiness Strategies\nNVIDIA’s key strategies that shape our overall business approach include:"),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='Advancing the NVIDIA accelerated computing platform. NVIDIA’s accelerated computing platform can solve complex problems in\nsignificantly less time and with lower power consumption than alternative computational approaches. Indeed, it can help solve problems that\nwere previously deemed unsolvable. We work to deliver continued performance leaps that outpace Moore’s Law by leveraging innovation across'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='the architecture, chip design, system, interconnect, and software layers. This full-stack innovation approach allows us to deliver order-of-\nmagnitude performance advantages relative to legacy approaches in our target markets, which include Data Center, Gaming, Professional\nVisualization, and Automotive. While the computing requirements of these end markets are diverse, we address them with a unified underlying'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='architecture leveraging our GPUs, CUDA and networking technologies as the fundamental building blocks. The programmable nature of our\narchitecture allows us to make leveraged investments in research and development: we can support several multi-billion-dollar end markets with\nshared underlying technology by using a variety of software stacks developed either internally or by third-party developers and partners. We\nutilize this platform approach in each of our target markets.'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='Extending our technology and platform leadership in AI. We provide a complete, end-to-end accelerated computing platform for deep\nlearning and machine learning, addressing both training and inferencing. This includes GPUs, interconnects, systems, our CUDA programming\nlanguage, algorithms, libraries, and other software. GPUs are uniquely suited to AI, and we will continue to add AI-specific features to our GPU'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='architecture to further extend our leadership position. Our AI technology leadership is reinforced by our large and expanding ecosystem in a\nvirtuous cycle. Our GPU platforms are available from virtually every major server maker and CSP, as well as on our own AI supercomputer.\nThere are 3.8 million developers worldwide using CUDA and our other software tools to help deploy our technology in our target markets. We'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='evangelize AI through partnerships with hundreds of universities and over 13,000 startups through our Inception program. Additionally, our Deep\nLearning Institute provides instruction on the latest techniques on how to design, train, and deploy neural networks in applications using our\naccelerated computing platform.\nExtending our technology and platform leadership in computer graphics. We believe that computer graphics is fundamental to the'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='continued expansion and evolution of computing. We apply our research and development resources to enhance the user experience for\nconsumer entertainment and professional visualization applications, and create new virtual world and simulation capabilities. Our technologies\nare instrumental in driving gaming forward, as developers leverage our libraries and algorithms to deliver an optimized gaming experience on our'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='GeForce platform. Our computer graphics platforms leverage not only our industry-leading GeForce and NVIDIA RTX GPUs, but also optimized\nsoftware stacks. For example, GeForce Experience enhances each gamer’s experience by optimizing their PC’s settings, as well as enabling the\nrecording and sharing of gameplay. Our Studio drivers enhance and accelerate a number of popular creative applications. Omniverse is real-'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='time 3D design collaboration and virtual world simulation software that empowers artists, designers and creators to connect and collaborate in\nleading design applications. We also enable interactive graphics applications - such as games, movie and photo editing and design software - to\nbe accessed by almost any device, almost anywhere, through our cloud platforms such as vGPU for enterprise and GeForce NOW for gaming.'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='Advancing the leading autonomous vehicle platform. We believe the advent of AV will soon revolutionize the transportation industry. In our\nview, AI is the key technology enabler of this opportunity, as the algorithms required for autonomous driving - such as perception, localization,\nand planning - are too complex for legacy hand-coded approaches and will use multiple trained neural networks instead. Therefore, we provide a'),
#   Document(metadata={'page': 7, 'type': 'text'}, page_content='full functionally safe AI-based hardware and software solution for the AV market under the DRIVE brand, which we are bringing to market\nthrough our partnerships with automotive original equipment manufacturers, or\n8'),
#   Document(metadata={'page': 8, 'type': 'text'}, page_content='Table of Contents\nOEMs, tier-1 suppliers, and start-ups. Our AV solution also includes the GPU-based hardware required to train the neural networks before their\nin-vehicle deployment, as well as to re-simulate their operation prior to any over-the-air software updates. We believe our comprehensive, top-to-\nbottom and end-to-end approach will enable the transportation industry to solve the complex problems arising from the shift to autonomous\ndriving.'),
#   Document(metadata={'page': 8, 'type': 'text'}, page_content='driving.\nLeveraging our intellectual property, or IP. We believe our IP is a valuable asset that can be accessed by our customers and partners through\nlicense and development agreements when they desire to build such capabilities directly into their own products, or have us do so through a\ncustom development. Such license and development arrangements can further enhance the reach of our technology.\nSales and Marketing'),
#   Document(metadata={'page': 8, 'type': 'text'}, page_content="Sales and Marketing\nOur worldwide sales and marketing strategy is key to achieving our objective of providing markets with our high-performance and efficient\ncomputing platforms and software. Our sales and marketing teams, located across our global markets, work closely with end customers and\nvarious industry ecosystems through our partner network. Our partner network incorporates each industry's respective OEMs, original device"),
#   Document(metadata={'page': 8, 'type': 'text'}, page_content='manufacturers, or ODMs, system builders, add-in board manufacturers, or AIBs, retailers/distributors, ISVs, internet and CSPs, automotive\nmanufacturers and tier-1 automotive suppliers, mapping companies, start-ups, and other ecosystem participants.\nMembers of our sales team have technical expertise and product and industry knowledge. We also employ a team of application engineers and'),
#   Document(metadata={'page': 8, 'type': 'text'}, page_content='solution architects to assist our partner network in designing, testing, and qualifying system designs that incorporate our platforms. We believe\nthat the depth and quality of our design support are key to improving our partner network’s time-to-market, maintaining a high level of customer\nsatisfaction, and fostering relationships that encourage our end customers and partner network to use the next generation of our products within\neach platform.'),
#   Document(metadata={'page': 8, 'type': 'text'}, page_content='each platform.\nTo encourage the development of applications optimized for our platforms and software, we seek to establish and maintain strong relationships\nin the software development community. Engineering and marketing personnel engage with key software developers to promote and discuss our\nplatforms, as well as to ascertain individual product requirements and solve technical problems. Our developer program makes our products'),
#   Document(metadata={'page': 8, 'type': 'text'}, page_content='available to developers prior to launch in order to encourage the development of AI frameworks, SDKs, and APIs for software applications and\ngame titles that are optimized for our platforms. Our Deep Learning Institute provides in-person and online training for developers in industries\nand organizations around the world to build AI and accelerated computing applications that leverage our platforms.'),
#   Document(metadata={'page': 8, 'type': 'text'}, page_content='As NVIDIA’s business has evolved from a focus primarily on gaming products to broader markets, and from chips to platforms, systems and\nsoftware, so, too, have our avenues to market. Thus, in addition to sales to customers in our partner network, certain of our products are also\nsold direct to CSPs, enterprise customers, retail channels and consumers.\nSeasonality'),
#   Document(metadata={'page': 8, 'type': 'text'}, page_content='Seasonality\nOur computing platforms serve a diverse set of markets such as consumer gaming, enterprise and cloud data centers, professional workstations,\nand automotive. Our consumer products typically see stronger revenue in the second half of our fiscal year. In addition, based on the production\nschedules of key customers, some of our products for notebooks and game consoles typically generate stronger revenue in the second and third'),
#   Document(metadata={'page': 8, 'type': 'text'}, page_content='quarters, and weaker revenue in the fourth and first quarters. In fiscal year 2023, our supply exceeded our demand in several areas, and our\nrevenue did not follow historical seasonal patterns. Historical seasonality trends may not repeat.\nManufacturing\nWe do not manufacture semiconductors used for our products. Instead, we utilize a fabless manufacturing strategy, whereby we employ key'),
#   Document(metadata={'page': 8, 'type': 'text'}, page_content='suppliers for all phases of the manufacturing process, including wafer fabrication, assembly, testing, and packaging. This strategy uses the\nexpertise of industry-leading suppliers that are certified by the International Organization for Standardization in such areas as fabrication,\nassembly, quality control and assurance, reliability, and testing. Additionally, we can avoid many of the significant costs and risks associated with'),
#   Document(metadata={'page': 8, 'type': 'text'}, page_content='owning and operating manufacturing operations. While we may directly procure certain raw materials used in the production of our products,\nsuch as memory, substrates and a variety of components, our suppliers are responsible for procurement of most of the raw materials used in the\n9'),
#   Document(metadata={'page': 9, 'type': 'text'}, page_content='Table of Contents\nproduction of our products. As a result, we can focus our resources on product design, additional quality assurance, marketing, and customer\nsupport. We have placed non-cancellable inventory orders for certain product components in advance of our historical lead times, paid premiums\nand provided deposits to secure future supply and capacity and may need to continue to do so in the future.'),
#   Document(metadata={'page': 9, 'type': 'text'}, page_content='We have expanded our supplier relationships to build redundancy and resilience in our operations. We utilize suppliers, such as Taiwan\nSemiconductor Manufacturing Company Limited and Samsung Electronics Co. Ltd, to produce our semiconductor wafers. We then utilize\nindependent subcontractors and contract manufacturers, such as Amkor Technology, BYD Auto Co. Ltd., or BYD Auto, Hon Hai Precision'),
#   Document(metadata={'page': 9, 'type': 'text'}, page_content='Industry Co., or Hon Hai, King Yuan Electronics Co., Ltd., Omni Logistics, LLC, Siliconware Precision Industries Company Ltd., and Wistron\nCorporation to perform assembly, testing, and packaging of most of our products and platforms. We use contract manufacturers such as Flex\nLtd., Jabil Inc., and Universal Scientific Industrial Co., Ltd., to manufacture our standard and custom adapter card products and switch systems,'),
# ...
#   Document(metadata={'page': 110, 'type': 'text'}, page_content='constructively, within a designated period following the occurrence of a Change in Control, but in the absence of such provision, no such\nacceleration will occur.\n10. Termination or Suspension of the Plan.\n(a) Plan Term. Unless sooner terminated by the Board pursuant to Section 2, the Plan will automatically terminate on the day before the\ntenth (10th) anniversary of the earlier of (i) the date the Plan is adopted by the Board or a duly authorized Committee, or (ii) the date the Plan is'),
#   Document(metadata={'page': 110, 'type': 'text'}, page_content='approved by the stockholders of the Company. The Board may suspend the Plan at anytime. No Awards may be granted under the Plan while\nthe Plan is suspended or after it is terminated.\n11. Effective Date of Plan.\nThis Plan will become effective on the Effective Date.\n12. Choice of Law.\nThe law of the State of Delaware will govern all questions concerning the construction, validity and interpretation of this Plan, without regard\nto that state’s conflict of laws rules.\n13. Definitions.'),
#   Document(metadata={'page': 110, 'type': 'text'}, page_content='13. Definitions.\nAs used in the Plan, the following definitions will apply to the capitalized terms indicated below:\n(a) “Affiliate” means, at the time of determination, any “parent” or “subsidiary” of the Company as such terms are defined in Rule 405 of the\nSecurities Act. The Board will have the authority to determine the time or times at which “parent” or “subsidiary” status is determined within the\nforegoing definition.\n(b) “Award” means a Stock Award or a Performance Cash Award.'),
#   Document(metadata={'page': 110, 'type': 'text'}, page_content='(c) “Award Agreement” means a written agreement between the Company and a Participant evidencing the terms and conditions of an\nAward.\n(d) “Board” means the Board of Directors of the Company.\n(e) “Capitalization Adjustment” means any change that is made in, or other events that occur with respect to, the Common Stock subject\nto the Plan or subject to any Stock Award after the Effective Date without the receipt of consideration by the Company through merger,'),
#   Document(metadata={'page': 110, 'type': 'text'}, page_content='consolidation, reorganization, recapitalization, reincorporation, stock dividend, dividend in property other than cash, stock split, liquidating\ndividend, combination of shares, exchange of shares, change in corporate structure or any similar equity restructuring transaction, as that term is\nused in Financial Accounting Standards Board Accounting Standards Codification Topic 718 (or any successor thereto). Notwithstanding the'),
#   Document(metadata={'page': 110, 'type': 'text'}, page_content='foregoing, the conversion of any convertible securities of the Company will not be treated as a Capitalization Adjustment.\n(f)\n“Cause” means (i) if a Participant is party to an agreement with the Company or an Affiliate that relates to equity awards and contains a\ndefinition of “Cause,” the definition of “Cause” in the applicable agreement, or (ii) if a Participant is not party to any such agreement, such'),
#   Document(metadata={'page': 110, 'type': 'text'}, page_content='Participant’s termination because of (A) any willful, material violation by the Participant of any law or regulation applicable to the business of the\nCompany or an Affiliate, the Participant’s conviction for, or guilty plea to, a felony or a crime involving moral turpitude, or any willful perpetration\nby the Participant of a common law fraud, (B) the Participant’s commission of an act of personal dishonesty that involves personal profit in'),
#   Document(metadata={'page': 111, 'type': 'text'}, page_content='connection with the Company or any other entity having a business relationship with the Company, (C) any material breach by the Participant of\nany provision of any agreement or understanding between the Company or an Affiliate and the Participant regarding the terms of the\nParticipant’s service as an Employee, Officer, Director or Consultant to the Company or an Affiliate, including without limitation, the willful and'),
#   Document(metadata={'page': 111, 'type': 'text'}, page_content='continued failure or refusal of the Participant to perform the material duties required of such Participant as an Employee, Officer, Director or\nConsultant of the Company or an Affiliate, other than as a result of having a Disability, or a breach of any applicable invention assignment and\nconfidentiality agreement or similar agreement between the Company or an Affiliate and the Participant, (D) the Participant’s disregard of the'),
#   Document(metadata={'page': 111, 'type': 'text'}, page_content='policies of the Company or an Affiliate so as to cause loss, damage or injury to the property, reputation or employees of the Company or an\nAffiliate, or (E) any other misconduct by the Participant that is materially injurious to the financial condition or business reputation of, or is\notherwise materially injurious to, the Company or an Affiliate.\n(g)  “Change in Control” means the occurrence, in a single transaction or in a series of related transactions, of any one or more of the'),
#   Document(metadata={'page': 111, 'type': 'text'}, page_content='following events:\n(i)\nany Exchange Act Person becomes the Owner, directly or indirectly, of securities of the Company representing more than 50%\nof the combined voting power of the Company’s then outstanding securities other than by virtue of a merger, consolidation or similar transaction.\nNotwithstanding the foregoing, a Change in Control will not be deemed to occur (A) on account of the acquisition of securities of the Company by'),
#   Document(metadata={'page': 111, 'type': 'text'}, page_content='an investor, any affiliate thereof or any other Exchange Act Person that acquires the Company’s securities in a transaction or series of related\ntransactions the primary purpose of which is to obtain financing for the Company through the issuance of equity securities, or (B) solely because\nthe level of Ownership held by any Exchange Act Person (the “Subject Person”) exceeds the designated percentage threshold of the'),
#   Document(metadata={'page': 111, 'type': 'text'}, page_content='outstanding voting securities as a result of a repurchase or other acquisition of voting securities by the Company reducing the number of shares\noutstanding, provided that if a Change in Control would occur (but for the operation of this sentence) as a result of the acquisition of voting\nsecurities by the Company, and after such share acquisition, the Subject Person becomes the Owner of any additional voting securities that,'),
#   Document(metadata={'page': 111, 'type': 'text'}, page_content='assuming the repurchase or other acquisition had not occurred, increases the percentage of the then outstanding voting securities Owned by the\nSubject Person over the designated percentage threshold, then a Change in Control will be deemed to occur;\n(ii)\nthere is consummated a merger, consolidation or similar transaction involving (directly or indirectly) the Company and,'),
#   Document(metadata={'page': 111, 'type': 'text'}, page_content='immediately after the consummation of such merger, consolidation or similar transaction, the stockholders of the Company immediately prior\nthereto do not Own, directly or indirectly, either (A) outstanding voting securities representing more than 50% of the combined outstanding voting\npower of the surviving Entity in such merger, consolidation or similar transaction or (B) more than 50% of the combined outstanding voting power'),
#   Document(metadata={'page': 111, 'type': 'text'}, page_content='of the parent of the surviving Entity in such merger, consolidation or similar transaction, in each case in substantially the same proportions as\ntheir Ownership of the outstanding voting securities of the Company immediately prior to such transaction;\n(iii)\nthere is consummated a sale, lease, exclusive license or other disposition of all or substantially all of the consolidated assets of'),
#   Document(metadata={'page': 111, 'type': 'text'}, page_content='the Company and its Subsidiaries, other than a sale, lease, license or other disposition of all or substantially all of the consolidated assets of the\nCompany and its Subsidiaries to an Entity, more than 50% of the combined voting power of the voting securities of which are Owned by\nstockholders of the Company in substantially the same proportions as their Ownership of the outstanding voting securities of the Company\nimmediately prior to such sale, lease, license or other disposition; or\n(iv)'),
#   Document(metadata={'page': 111, 'type': 'text'}, page_content='(iv)\nindividuals who, on the date this Plan is adopted by the Board, are members of the Board (the “Incumbent Board”) cease for\nany reason to constitute at least a majority of the members of the Board; provided, however, that if the appointment or election (or nomination for\nelection) of any new Board member was approved or recommended by a majority vote of the members of the Incumbent Board then still in'),
#   Document(metadata={'page': 111, 'type': 'text'}, page_content='office, such new member will, for purposes of this Plan, be considered as a member of the Incumbent Board.\nFor purposes of determining voting power under the term Change in Control, voting power will be calculated by assuming the conversion of\nall equity securities convertible (immediately or at some future time) into shares entitled to'),
#   Document(metadata={'page': 112, 'type': 'text'}, page_content='vote, but not assuming the exercise of any warrant or right to subscribe to or purchase those shares. In addition, (A) the term Change in Control\nwill not include a sale of assets, merger or other transaction effected exclusively for the purpose of changing the domicile of the Company, and\n(B) the definition of Change in Control (or any analogous term) in an individual written agreement between the Company or any Affiliate and the'),
#   Document(metadata={'page': 112, 'type': 'text'}, page_content='Participant will supersede the foregoing definition with respect to Awards subject to such agreement; provided, however, that if no definition of\nChange in Control or any analogous term is set forth in such an individual written agreement, the foregoing definition will apply; provided, further,\nthat no Change in Control will be deemed to occur upon announcement or commencement of a tender offer or upon a potential takeover or upon'),
#   Document(metadata={'page': 112, 'type': 'text'}, page_content='stockholder approval of a merger or other transaction, in each case without a requirement that the Change in Control actually occur.\nIf required for compliance with Section 409A of the Code, in no event will a Change in Control be deemed to have occurred if such\ntransaction is not also a “change in the ownership or effective control of” the Company or “a change in the ownership of a substantial portion of'),
#   Document(metadata={'page': 112, 'type': 'text'}, page_content='the assets of” the Company as determined under Treasury Regulation Section 1.409A-3(i)(5) (without regard to any alternative definition\nthereunder). The Board may, in its sole discretion and without a Participant’s consent, amend the definition of “Change in Control” to conform to\nthe definition of “Change in Control” under Section 409A of the Code and the regulations thereunder.'),
#   Document(metadata={'page': 112, 'type': 'text'}, page_content='(h) “Code” means the Internal Revenue Code of 1986, as amended, including any applicable regulations and guidance thereunder.\n(i)\n“Committee” means a committee of one (1) or more Directors to whom authority has been delegated by the Board in accordance with\nSection 2(c).\n(j)\n“Common Stock” means the common stock of the Company.\n(k) “Company” means NVIDIA Corporation, a Delaware corporation.\n(l)'),
#   Document(metadata={'page': 112, 'type': 'text'}, page_content='(l)\n“Consultant” means any person, including an advisor, who is (i) engaged by the Company or an Affiliate to render consulting or advisory\nservices and is compensated for such services, or (ii) serving as a member of the board of directors of an Affiliate and is compensated for such\nservices. However, service solely as a Director, or payment of a fee for such service, will not cause a Director to be considered a “Consultant” for\npurposes of the Plan.'),
#   Document(metadata={'page': 112, 'type': 'text'}, page_content='purposes of the Plan.\n(m) “Continuous Service” means that the Participant’s service with the Company or an Affiliate, whether as an Employee, Director or\nConsultant, is not interrupted or terminated. A change in the capacity in which the Participant renders service to the Company or an Affiliate as\nan Employee, Consultant or Director or a change in the entity for which the Participant renders such service, provided that there is no'),
#   Document(metadata={'page': 112, 'type': 'text'}, page_content='interruption or termination of the Participant’s service with the Company or an Affiliate, will not terminate a Participant’s Continuous Service;\nprovided, however, that if the Entity for which a Participant is rendering services ceases to qualify as an “Affiliate” as determined by the Board in\nits sole discretion, such Participant’s Continuous Service will be considered to have terminated on the date such Entity ceases to qualify as an'),
#   Document(metadata={'page': 112, 'type': 'text'}, page_content='Affiliate. To the extent permitted by law, the Board or the chief executive officer of the Company, in that party’s sole discretion, may determine\nwhether Continuous Service will be considered interrupted in the case of: (i) any leave of absence approved by the Board of the chief executive\nofficer of the Company, including sick leave, military leave or any other personal leave; or (ii) transfers between the Company, an Affiliate, or their'),
#   Document(metadata={'page': 112, 'type': 'text'}, page_content='successors. Notwithstanding the foregoing, and except as otherwise required by applicable law or as otherwise determined by the Committee, a\nleave of absence will be treated as Continuous Service for purposes of vesting in an Award only on those days on which the Participant is using\nCompany-paid vacation time and floating holidays and for the first 90 days of leave during which the Participant is not being paid through such'),
#   Document(metadata={'page': 112, 'type': 'text'}, page_content='vacation time and floating holidays. In addition, to the extent required for exemption from or compliance with Section 409A of the Code, the\ndetermination of whether there has been a termination of Continuous Service will be made, and such term will be construed, in a manner that is\nconsistent with the definition of “separation from service” as defined under Treasury Regulation Section 1.409A-1(h) (without regard to any\nalternative definition thereunder).'),
#   ...],
#  array([[-0.01287598,  0.04877269, -0.03023132, ..., -0.00654506,
#          -0.00766676,  0.00073045],
#         [-0.01041544, -0.01405487, -0.01962452, ...,  0.05553675,
#          -0.00819241, -0.04919571],
#         [ 0.0227439 , -0.00631156, -0.01333825, ...,  0.06064708,
#           0.00826883, -0.04080103],
#         ...,
#         [ 0.03837572, -0.00354057, -0.02518085, ...,  0.04864152,
#           0.00831235, -0.02403388],
#         [ 0.01557035,  0.0022552 , -0.00702683, ...,  0.07278122,
#           0.00739336, -0.0662268 ],
#         [ 0.00908183,  0.03708636,  0.00511615, ..., -0.02527341,
#           0.00203589, -0.0146383 ]], dtype=float32))

# %%
import faiss
from langchain_community.vectorstores import FAISS

# %%
vector_store=FAISS.from_embeddings(
    text_embeddings=[(doc.page_content,emb) for doc,emb in zip(all_docs,embeddings_array)],
    embedding=None,
    metadatas=[doc.metadata for doc in all_docs]    
)
# Out:
# `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %%
vector_store

# %%
vector_store.save_local("ReportVectorDB")

# %%
vector_store

# %%
import json
with open("image_data_store.json","w") as f:
    json.dump(image_data_store,f)

# %%
#creating method to retrieve text related to query

def docs_retrieval_based_query(query:str,k:int):
    """"Unified retrival using clip embedding model"""
    query_embedding=embed_text(query)

    retrived_docs=vector_store.asimilarity_search_by_vector(
        embedding=query_embedding,
        k=k
    )
    retrived_docs

# %%
def multimodel_query_message(query: str, retrieved_docs: list[Document]):
    """Create a complete message to pass to the model for a particular query."""

    context = [
        {
            "type": "text",
            "text": f"Question: {query}\n\nContext:\n"
        }
    ]

    text_docs = [doc for doc in retrieved_docs if doc.metadata.get("type") == "text"]
    image_docs = [doc for doc in retrieved_docs if doc.metadata.get("type") == "image"]
    table_docs = [doc for doc in retrieved_docs if doc.metadata.get("type") == "table"]

    # Add text docs
    if text_docs:
        text_context = "\n\n".join([
            f"[Page: {doc.metadata.get('page')}] : {doc.page_content}" for doc in text_docs
        ])
        context.append({
            "type": "text",
            "text": f"Text excerpts: {text_context}"
        })

    # Add images
    for doc in image_docs:
        image_id = doc.metadata.get("image_id")
        if image_id and image_id in image_data_store:
            context.append({
                "type": "text",
                "text": f"[Image from page {doc.metadata.get('page')}]"
            })
            context.append({
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/png;base64,{image_data_store[image_id]}"
                }
            })

    # Add tables with optional summaries
    for doc in table_docs:
        table_content = doc.page_content
        context.append({
            "type": "text",
            "text": f"[Table from page {doc.metadata.get('page')} - method: {doc.metadata.get('method')}] Content: {table_content}"
        })

        
    context.append({
        "type": "text",
        "text": "Please generate a response to the user's query based on the context above. "
                "If the context is insufficient, reply that there is not enough information to answer the query."
    })

    return context
